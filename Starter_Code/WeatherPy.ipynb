# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping... {e}")
        pass

    # Pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sisimiut
# Processing Record 2 of Set 1 | tranovaho
# City not found. Skipping... 'coord'
# Processing Record 3 of Set 1 | coronel suarez
# Processing Record 4 of Set 1 | boa vista
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | tura
# Processing Record 8 of Set 1 | chinde
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | edinburgh of the seven seas
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | hamilton
# Processing Record 15 of Set 1 | college
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | whitehorse
# Processing Record 19 of Set 1 | batalha
# Processing Record 20 of Set 1 | recani
# Processing Record 21 of Set 1 | adamstown
# Processing Record 22 of Set 1 | port shepstone
# Processing Record 23 of Set 1 | taroa
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | uturoa
# Processing Record 26 of Set 1 | villa gesell
# Processing Record 27 of Set 1 | taiohae
# City not found. Skipping... 'coord'
# Processing Record 28 of Set 1 | kyzyl-mazhalyk
# Processing Record 29 of Set 1 | nova sintra
# Processing Record 30 of Set 1 | yonggwang-up
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | berdigestyakh
# Processing Record 34 of Set 1 | west island
# Processing Record 35 of Set 1 | isafjordur
# Processing Record 36 of Set 1 | lompoc
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | mil'kovo
# Processing Record 39 of Set 1 | sao vicente
# Processing Record 40 of Set 1 | timbuktu
# Processing Record 41 of Set 1 | antsiranana
# Processing Record 42 of Set 1 | boguchany
# Processing Record 43 of Set 1 | bandon
# Processing Record 44 of Set 1 | bubaque
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | constantia
# Processing Record 47 of Set 1 | howrah
# Processing Record 48 of Set 1 | carolina beach
# Processing Record 49 of Set 1 | fuvahmulah
# City not found. Skipping... 'coord'
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 0 of Set 2 | new plymouth
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | laikit, laikit ii (dimembe)
# Processing Record 4 of Set 2 | hofors
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | puerto natales
# Processing Record 7 of Set 2 | paraparaumu
# Processing Record 8 of Set 2 | hammerfest
# Processing Record 9 of Set 2 | tolanaro
# Processing Record 10 of Set 2 | gurupi
# Processing Record 11 of Set 2 | umba
# Processing Record 12 of Set 2 | roma
# Processing Record 13 of Set 2 | weno
# Processing Record 14 of Set 2 | kuressaare
# Processing Record 15 of Set 2 | zaozersk
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | dalandzadgad
# Processing Record 18 of Set 2 | aubange
# Processing Record 19 of Set 2 | mwinilunga
# Processing Record 20 of Set 2 | huaihua
# Processing Record 21 of Set 2 | stanley
# Processing Record 22 of Set 2 | opuwo
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | campo gallo
# Processing Record 25 of Set 2 | bhuj
# Processing Record 26 of Set 2 | wailua homesteads
# Processing Record 27 of Set 2 | quezon
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | port glaud
# City not found. Skipping... 'coord'
# Processing Record 30 of Set 2 | kargat
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | alaghsas
# Processing Record 33 of Set 2 | maiyama
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | blackmans bay
# Processing Record 36 of Set 2 | broken hill
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | ambatofinandrahana
# Processing Record 39 of Set 2 | burang
# Processing Record 40 of Set 2 | ugoofaaru
# Processing Record 41 of Set 2 | urangan
# Processing Record 42 of Set 2 | nemuro
# Processing Record 43 of Set 2 | faya-largeau
# Processing Record 44 of Set 2 | san antonio de pale
# Processing Record 45 of Set 2 | autun
# Processing Record 46 of Set 2 | egilsstadir
# Processing Record 47 of Set 2 | maun
# Processing Record 48 of Set 2 | niafunke
# Processing Record 49 of Set 2 | utrik
# Processing Record 0 of Set 3 | gadzhiyevo
# Processing Record 1 of Set 3 | suva
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | pacific grove
# Processing Record 4 of Set 3 | saudarkrokur
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | port lincoln
# Processing Record 7 of Set 3 | prince rupert
# Processing Record 8 of Set 3 | richards bay
# Processing Record 9 of Set 3 | rio grande
# Processing Record 10 of Set 3 | oliver
# Processing Record 11 of Set 3 | karakulino
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | olonkinbyen
# Processing Record 15 of Set 3 | les cayes
# Processing Record 16 of Set 3 | deqen
# Processing Record 17 of Set 3 | papatowai
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | bilibino
# Processing Record 20 of Set 3 | vadso
# Processing Record 21 of Set 3 | lihue
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | saint-francois
# Processing Record 24 of Set 3 | invercargill
# Processing Record 25 of Set 3 | sandnessjoen
# Processing Record 26 of Set 3 | bargara
# City not found. Skipping... 'coord'
# Processing Record 27 of Set 3 | khanty-mansiysk
# Processing Record 28 of Set 3 | hami
# Processing Record 29 of Set 3 | alotau
# Processing Record 30 of Set 3 | kastsyukowka
# Processing Record 31 of Set 3 | afif
# Processing Record 32 of Set 3 | chibougamau
# Processing Record 33 of Set 3 | hayma'
# City not found. Skipping... 'coord'
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | zouerate
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | chimore
# Processing Record 38 of Set 3 | maintirano
# Processing Record 39 of Set 3 | morant bay
# Processing Record 40 of Set 3 | quincy
# Processing Record 41 of Set 3 | klyuchi
# Processing Record 42 of Set 3 | lincoln
# Processing Record 43 of Set 3 | rongelap
# Processing Record 44 of Set 3 | pokrovsk
# Processing Record 45 of Set 3 | saldanha
# Processing Record 46 of Set 3 | kimbe
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | holualoa
# Processing Record 49 of Set 3 | djambala
# Processing Record 0 of Set 4 | tengrela
# Processing Record 1 of Set 4 | qarqaraly
# Processing Record 2 of Set 4 | port augusta
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | north shore
# Processing Record 5 of Set 4 | santa cruz
# Processing Record 6 of Set 4 | anadyr
# Processing Record 7 of Set 4 | quixada
# Processing Record 8 of Set 4 | atafu village
# Processing Record 9 of Set 4 | namibe
# Processing Record 10 of Set 4 | vilyuysk
# Processing Record 11 of Set 4 | leua
# Processing Record 12 of Set 4 | rojhan
# Processing Record 13 of Set 4 | toliara
# Processing Record 14 of Set 4 | kuching
# Processing Record 15 of Set 4 | arkhangel'sk
# Processing Record 16 of Set 4 | novyy urgal
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | santa catalina
# Processing Record 19 of Set 4 | aljezur
# Processing Record 20 of Set 4 | vorgashor
# Processing Record 21 of Set 4 | nanping
# Processing Record 22 of Set 4 | cockburn town
# Processing Record 23 of Set 4 | sabzevar
# Processing Record 24 of Set 4 | port mathurin
# Processing Record 25 of Set 4 | iskateley
# Processing Record 26 of Set 4 | tevriz
# Processing Record 27 of Set 4 | eureka
# Processing Record 28 of Set 4 | lagunas
# Processing Record 29 of Set 4 | nar'yan-mar
# Processing Record 30 of Set 4 | moree
# Processing Record 31 of Set 4 | margaret river
# Processing Record 32 of Set 4 | masterton
# Processing Record 33 of Set 4 | selfoss
# Processing Record 34 of Set 4 | al jawf
# Processing Record 35 of Set 4 | mukah
# City not found. Skipping... 'coord'
# Processing Record 36 of Set 4 | qaqortoq
# Processing Record 37 of Set 4 | baglung
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | long beach
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | paravur tekkumbhagam
# Processing Record 43 of Set 4 | green river
# Processing Record 44 of Set 4 | mananjary
# Processing Record 45 of Set 4 | longboat key
# Processing Record 46 of Set 4 | waat
# Processing Record 47 of Set 4 | enewetak
# Processing Record 48 of Set 4 | hadibu
# Processing Record 49 of Set 4 | vytegra
# Processing Record 0 of Set 5 | tejen
# Processing Record 1 of Set 5 | rada tilly
# Processing Record 2 of Set 5 | tazovsky
# Processing Record 3 of Set 5 | podgornoye
# Processing Record 4 of Set 5 | puerto san jose
# Processing Record 5 of Set 5 | glace bay
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | trancas
# Processing Record 8 of Set 5 | awjilah
# Processing Record 9 of Set 5 | ljusdal
# Processing Record 10 of Set 5 | agat village
# Processing Record 11 of Set 5 | si sa ket
# Processing Record 12 of Set 5 | lesogorsk
# Processing Record 13 of Set 5 | ebon
# Processing Record 14 of Set 5 | socorro
# Processing Record 15 of Set 5 | udachny
# Processing Record 16 of Set 5 | ust-nera
# Processing Record 17 of Set 5 | altay
# Processing Record 18 of Set 5 | lospalos
# Processing Record 19 of Set 5 | ribeira brava
# Processing Record 20 of Set 5 | barrouallie
# Processing Record 21 of Set 5 | fada
# Processing Record 22 of Set 5 | sumbe
# Processing Record 23 of Set 5 | magadan
# Processing Record 24 of Set 5 | badger
# Processing Record 25 of Set 5 | yeppoon
# Processing Record 26 of Set 5 | winnemucca
# Processing Record 27 of Set 5 | ust'-kut
# Processing Record 28 of Set 5 | mareeba
# Processing Record 29 of Set 5 | youhao
# Processing Record 30 of Set 5 | ahau
# City not found. Skipping... 'coord'
# Processing Record 31 of Set 5 | kingston
# Processing Record 32 of Set 5 | amble
# Processing Record 33 of Set 5 | saipan
# Processing Record 34 of Set 5 | pangkalpinang
# Processing Record 35 of Set 5 | thal
# Processing Record 36 of Set 5 | hawaiian paradise park
# Processing Record 37 of Set 5 | mata-utu
# Processing Record 38 of Set 5 | nikolayevsk-on-amure
# Processing Record 39 of Set 5 | cartagena del chaira
# Processing Record 40 of Set 5 | qulsary
# Processing Record 41 of Set 5 | kristiansund
# Processing Record 42 of Set 5 | callao
# Processing Record 43 of Set 5 | borca
# Processing Record 44 of Set 5 | kailua-kona
# Processing Record 45 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 5 | san jose village
# City not found. Skipping... 'coord'
# Processing Record 47 of Set 5 | tual
# Processing Record 48 of Set 5 | turpan
# Processing Record 49 of Set 5 | afaahiti
# Processing Record 0 of Set 6 | ancud
# Processing Record 1 of Set 6 | cholpon-ata
# Processing Record 2 of Set 6 | kzyltu
# Processing Record 3 of Set 6 | am djarass
# City not found. Skipping... 'coord'
# Processing Record 4 of Set 6 | uglegorsk
# Processing Record 5 of Set 6 | bazarnyy syzgan
# Processing Record 6 of Set 6 | cabo san lucas
# Processing Record 7 of Set 6 | hauterive
# Processing Record 8 of Set 6 | nuuk
# Processing Record 9 of Set 6 | maloye ganyushkino
# Processing Record 10 of Set 6 | garcia
# Processing Record 11 of Set 6 | fale old settlement
# Processing Record 12 of Set 6 | bajil
# Processing Record 13 of Set 6 | lorengau
# Processing Record 14 of Set 6 | pirai do sul
# Processing Record 15 of Set 6 | mahajanga
# Processing Record 16 of Set 6 | sao raimundo nonato
# Processing Record 17 of Set 6 | umluj
# Processing Record 18 of Set 6 | rio gallegos
# Processing Record 19 of Set 6 | olinda
# Processing Record 20 of Set 6 | san julian
# Processing Record 21 of Set 6 | mejit
# Processing Record 22 of Set 6 | lautoka
# Processing Record 23 of Set 6 | phan rang-thap cham
# Processing Record 24 of Set 6 | happy valley-goose bay
# Processing Record 25 of Set 6 | narvik
# Processing Record 26 of Set 6 | colonia
# Processing Record 27 of Set 6 | fomboni
# Processing Record 28 of Set 6 | greenville
# Processing Record 29 of Set 6 | nogliki
# Processing Record 30 of Set 6 | flying fish cove
# Processing Record 31 of Set 6 | lucapa
# Processing Record 32 of Set 6 | karosta
# City not found. Skipping... 'coord'
# Processing Record 33 of Set 6 | tsiombe
# Processing Record 34 of Set 6 | yasuj
# Processing Record 35 of Set 6 | angaur state
# Processing Record 36 of Set 6 | peterhead
# Processing Record 37 of Set 6 | el obeid
# Processing Record 38 of Set 6 | cadale
# Processing Record 39 of Set 6 | tromso
# Processing Record 40 of Set 6 | mockrehna
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | polyarnyy
# Processing Record 43 of Set 6 | madalena
# Processing Record 44 of Set 6 | baturaja
# Processing Record 45 of Set 6 | chegdomyn
# Processing Record 46 of Set 6 | east london
# Processing Record 47 of Set 6 | santa luzia
# Processing Record 48 of Set 6 | nuwara eliya
# Processing Record 49 of Set 6 | doschatoye
# Processing Record 0 of Set 7 | upington
# Processing Record 1 of Set 7 | crane
# Processing Record 2 of Set 7 | kuanda
# Processing Record 3 of Set 7 | sao joao do paraiso
# Processing Record 4 of Set 7 | berezovyy
# Processing Record 5 of Set 7 | tadine
# Processing Record 6 of Set 7 | queenstown
# Processing Record 7 of Set 7 | saint croix
# Processing Record 8 of Set 7 | remire-montjoly
# Processing Record 9 of Set 7 | tezu
# Processing Record 10 of Set 7 | aasiaat
# Processing Record 11 of Set 7 | boldumsaz
# Processing Record 12 of Set 7 | kidal
# Processing Record 13 of Set 7 | manta
# Processing Record 14 of Set 7 | zhosaly
# Processing Record 15 of Set 7 | bani mazar
# Processing Record 16 of Set 7 | fredericksburg
# Processing Record 17 of Set 7 | la passe
# Processing Record 18 of Set 7 | swabi
# Processing Record 19 of Set 7 | eyl
# Processing Record 20 of Set 7 | punta cana
# Processing Record 21 of Set 7 | murakami
# Processing Record 22 of Set 7 | nkowakowa
# Processing Record 23 of Set 7 | ankang
# Processing Record 24 of Set 7 | ola
# Processing Record 25 of Set 7 | ust-tsilma
# Processing Record 26 of Set 7 | yazykovo
# Processing Record 27 of Set 7 | el nido
# Processing Record 28 of Set 7 | coruripe
# Processing Record 29 of Set 7 | pagar alam
# Processing Record 30 of Set 7 | puerto palomas
# Processing Record 31 of Set 7 | cassilandia
# Processing Record 32 of Set 7 | kampung sungai ara
# Processing Record 33 of Set 7 | lethem
# Processing Record 34 of Set 7 | zemio
# Processing Record 35 of Set 7 | kapa'a
# Processing Record 36 of Set 7 | kirandul
# City not found. Skipping... 'coord'
# Processing Record 37 of Set 7 | cargados carajos
# City not found. Skipping... 'coord'
# Processing Record 38 of Set 7 | basco
# Processing Record 39 of Set 7 | la punta
# Processing Record 40 of Set 7 | fort st. john
# Processing Record 41 of Set 7 | tynda
# Processing Record 42 of Set 7 | parnu
# Processing Record 43 of Set 7 | hasaki
# Processing Record 44 of Set 7 | fort bragg
# Processing Record 45 of Set 7 | atar
# Processing Record 46 of Set 7 | la tijera
# Processing Record 47 of Set 7 | haiku-pauwela
# Processing Record 48 of Set 7 | dudinka
# Processing Record 49 of Set 7 | kiunga
# Processing Record 0 of Set 8 | yakeshi
# Processing Record 1 of Set 8 | saint-philippe
# Processing Record 2 of Set 8 | orlovskiy
# Processing Record 3 of Set 8 | mihaileni
# Processing Record 4 of Set 8 | wuwei
# Processing Record 5 of Set 8 | hondarribia
# Processing Record 6 of Set 8 | la crosse
# Processing Record 7 of Set 8 | rundu
# Processing Record 8 of Set 8 | cable beach
# City not found. Skipping... 'coord'
# Processing Record 9 of Set 8 | oriximina
# Processing Record 10 of Set 8 | banda aceh
# Processing Record 11 of Set 8 | bhulath gharbi
# Processing Record 12 of Set 8 | mount gambier
# Processing Record 13 of Set 8 | tionk essil
# Processing Record 14 of Set 8 | praia da vitoria
# Processing Record 15 of Set 8 | mcrae
# Processing Record 16 of Set 8 | korla
# Processing Record 17 of Set 8 | antofagasta
# Processing Record 18 of Set 8 | uglich
# Processing Record 19 of Set 8 | viransehir
# Processing Record 20 of Set 8 | cherokee
# Processing Record 21 of Set 8 | northam
# Processing Record 22 of Set 8 | vilyuchinsk
# Processing Record 23 of Set 8 | khandyga
# Processing Record 24 of Set 8 | palikir - national government center
# Processing Record 25 of Set 8 | laguna
# Processing Record 26 of Set 8 | dar chioukh
# Processing Record 27 of Set 8 | thinadhoo
# Processing Record 28 of Set 8 | es castell
# Processing Record 29 of Set 8 | cole harbour
# Processing Record 30 of Set 8 | bonthe
# Processing Record 31 of Set 8 | kayenta
# Processing Record 32 of Set 8 | kerikeri
# Processing Record 33 of Set 8 | prince george
# Processing Record 34 of Set 8 | mukalla
# Processing Record 35 of Set 8 | necochea
# Processing Record 36 of Set 8 | berwick-upon-tweed
# Processing Record 37 of Set 8 | dunedin
# Processing Record 38 of Set 8 | pitiquito
# Processing Record 39 of Set 8 | benjamin constant
# Processing Record 40 of Set 8 | brisas de zicatela
# Processing Record 41 of Set 8 | sitia
# Processing Record 42 of Set 8 | mount isa
# Processing Record 43 of Set 8 | chonchi
# Processing Record 44 of Set 8 | la gomera
# Processing Record 45 of Set 8 | maebaru-chuo
# Processing Record 46 of Set 8 | emerald
# Processing Record 47 of Set 8 | gamba
# Processing Record 48 of Set 8 | zhanibek
# Processing Record 49 of Set 8 | fisterra
# Processing Record 0 of Set 9 | cururupu
# Processing Record 1 of Set 9 | port saint john's
# Processing Record 2 of Set 9 | satsuma
# Processing Record 3 of Set 9 | manavalakurichi
# Processing Record 4 of Set 9 | timbiqui
# Processing Record 5 of Set 9 | velikiy novgorod
# Processing Record 6 of Set 9 | bardai
# Processing Record 7 of Set 9 | anori
# Processing Record 8 of Set 9 | mermoz boabab
# Processing Record 9 of Set 9 | harper
# Processing Record 10 of Set 9 | kirando
# Processing Record 11 of Set 9 | labrador city
# Processing Record 12 of Set 9 | swift current
# Processing Record 13 of Set 9 | darwin
# Processing Record 14 of Set 9 | butte
# Processing Record 15 of Set 9 | mahibadhoo
# Processing Record 16 of Set 9 | brasileia
# Processing Record 17 of Set 9 | albion
# Processing Record 18 of Set 9 | megion
# Processing Record 19 of Set 9 | smara
# Processing Record 20 of Set 9 | cruz del eje
# Processing Record 21 of Set 9 | busan
# Processing Record 22 of Set 9 | issoudun
# Processing Record 23 of Set 9 | usogorsk
# Processing Record 24 of Set 9 | keflavik
# Processing Record 25 of Set 9 | saint-pierre
# Processing Record 26 of Set 9 | howard springs
# Processing Record 27 of Set 9 | pudozh
# Processing Record 28 of Set 9 | niceville
# Processing Record 29 of Set 9 | dunkwa
# Processing Record 30 of Set 9 | ciudad bolivar
# Processing Record 31 of Set 9 | federal way
# Processing Record 32 of Set 9 | betio village
# Processing Record 33 of Set 9 | puerto aysen
# Processing Record 34 of Set 9 | tindouf
# Processing Record 35 of Set 9 | flin flon
# Processing Record 36 of Set 9 | kibre mengist
# Processing Record 37 of Set 9 | betioky
# Processing Record 38 of Set 9 | susuman
# Processing Record 39 of Set 9 | miguel ahumada
# Processing Record 40 of Set 9 | kalaleh
# Processing Record 41 of Set 9 | zhangye
# Processing Record 42 of Set 9 | alice springs
# Processing Record 43 of Set 9 | jolo
# Processing Record 44 of Set 9 | mont-dore
# Processing Record 45 of Set 9 | jayapura
# Processing Record 46 of Set 9 | katsuren-haebaru
# Processing Record 47 of Set 9 | viedma
# Processing Record 48 of Set 9 | canubing no 2
# Processing Record 49 of Set 9 | devinuwara
# City not found. Skipping... 'coord'
# Processing Record 0 of Set 10 | leh
# Processing Record 1 of Set 10 | kolonia
# Processing Record 2 of Set 10 | nuh
# Processing Record 3 of Set 10 | levuka
# Processing Record 4 of Set 10 | saint-felicien
# Processing Record 5 of Set 10 | balezino
# Processing Record 6 of Set 10 | bikenibeu village
# Processing Record 7 of Set 10 | greenland
# Processing Record 8 of Set 10 | dhi as sufal
# Processing Record 9 of Set 10 | woolgoolga
# Processing Record 10 of Set 10 | matane
# Processing Record 11 of Set 10 | puerto san carlos
# City not found. Skipping... 'coord'
# Processing Record 12 of Set 10 | namsos
# Processing Record 13 of Set 10 | butterworth
# Processing Record 14 of Set 10 | mandera
# Processing Record 15 of Set 10 | onega
# Processing Record 16 of Set 10 | mega
# Processing Record 17 of Set 10 | toga village
# City not found. Skipping... 'coord'
# Processing Record 18 of Set 10 | mar del plata
# Processing Record 19 of Set 10 | qiryat shemona
# Processing Record 20 of Set 10 | sipote
# Processing Record 21 of Set 10 | prado
# Processing Record 22 of Set 10 | akrehamn
# Processing Record 23 of Set 10 | fuli
# Processing Record 24 of Set 10 | geraldton
# Processing Record 25 of Set 10 | ondjiva
# Processing Record 26 of Set 10 | ulety
# Processing Record 27 of Set 10 | prachuap khiri khan
# Processing Record 28 of Set 10 | samana
# Processing Record 29 of Set 10 | hihifo
# City not found. Skipping... 'coord'
# Processing Record 30 of Set 10 | riohacha
# Processing Record 31 of Set 10 | kavaratti
# Processing Record 32 of Set 10 | santa elena de uairen
# Processing Record 33 of Set 10 | aguas vermelhas
# Processing Record 34 of Set 10 | belmonte
# Processing Record 35 of Set 10 | xilin hot
# Processing Record 36 of Set 10 | barranca
# Processing Record 37 of Set 10 | machico
# Processing Record 38 of Set 10 | touros
# Processing Record 39 of Set 10 | rio claro
# Processing Record 40 of Set 10 | christchurch
# Processing Record 41 of Set 10 | kalefeld
# Processing Record 42 of Set 10 | san jose del guaviare
# Processing Record 43 of Set 10 | vila velha
# Processing Record 44 of Set 10 | novo selo
# Processing Record 45 of Set 10 | port blair
# Processing Record 46 of Set 10 | port said
# Processing Record 47 of Set 10 | irituia
# Processing Record 48 of Set 10 | pasni
# Processing Record 49 of Set 10 | turkestan
# Processing Record 0 of Set 11 | dom pedrito
# Processing Record 1 of Set 11 | kapuskasing
# Processing Record 2 of Set 11 | porto novo
# Processing Record 3 of Set 11 | pontianak
# Processing Record 4 of Set 11 | sao geraldo do araguaia
# Processing Record 5 of Set 11 | keetmanshoop
# Processing Record 6 of Set 11 | tanjung selor
# Processing Record 7 of Set 11 | ruthin
# Processing Record 8 of Set 11 | punta del este
# Processing Record 9 of Set 11 | yangor
# City not found. Skipping... 'coord'
# Processing Record 10 of Set 11 | buka
# Processing Record 11 of Set 11 | kavieng
# Processing Record 12 of Set 11 | mufulira
# Processing Record 13 of Set 11 | poronaysk
# Processing Record 14 of Set 11 | tazacorte
# Processing Record 15 of Set 11 | kirakira
# Processing Record 16 of Set 11 | yagry
# City not found. Skipping... 'coord'
# Processing Record 17 of Set 11 | imbituba
# Processing Record 18 of Set 11 | ponta delgada
# Processing Record 19 of Set 11 | san patricio
# Processing Record 20 of Set 11 | monrovia
# Processing Record 21 of Set 11 | sao joao da barra
# Processing Record 22 of Set 11 | lubang
# Processing Record 23 of Set 11 | bandundu
# Processing Record 24 of Set 11 | alofi
# Processing Record 25 of Set 11 | caleta de carquin
# Processing Record 26 of Set 11 | adelia maria
# Processing Record 27 of Set 11 | xinglongshan
# Processing Record 28 of Set 11 | lerwick
# Processing Record 29 of Set 11 | as samawah
# Processing Record 30 of Set 11 | albertina
# Processing Record 31 of Set 11 | galle
# Processing Record 32 of Set 11 | kete krachi
# Processing Record 33 of Set 11 | chipinge
# Processing Record 34 of Set 11 | maceio
# Processing Record 35 of Set 11 | akonolinga
# Processing Record 36 of Set 11 | kralendijk
# Processing Record 37 of Set 11 | vinh
# Processing Record 38 of Set 11 | vorkuta
# Processing Record 39 of Set 11 | shingu
# Processing Record 40 of Set 11 | rocky mountain house
# Processing Record 41 of Set 11 | maubin
# Processing Record 42 of Set 11 | hinton
# Processing Record 43 of Set 11 | beinamar
# Processing Record 44 of Set 11 | ratnagiri
# Processing Record 45 of Set 11 | lubao
# Processing Record 46 of Set 11 | klaksvik
# Processing Record 47 of Set 11 | altai
# Processing Record 48 of Set 11 | tralee
# Processing Record 49 of Set 11 | cukai
# Processing Record 0 of Set 12 | barra
# Processing Record 1 of Set 12 | mead
# Processing Record 2 of Set 12 | island harbour
# Processing Record 3 of Set 12 | wellington
# Processing Record 4 of Set 12 | borogontsy
# Processing Record 5 of Set 12 | trubchevsk
# Processing Record 6 of Set 12 | wildwood
# Processing Record 7 of Set 12 | herencia
# Processing Record 8 of Set 12 | vernon
# Processing Record 9 of Set 12 | archangelos
# Processing Record 10 of Set 12 | yuzhno-kurilsk
# Processing Record 11 of Set 12 | margate
# Processing Record 12 of Set 12 | berriane
# Processing Record 13 of Set 12 | freetown
# Processing Record 14 of Set 12 | taoudenni
# Processing Record 15 of Set 12 | lamu
# Processing Record 16 of Set 12 | chiredzi
# Processing Record 17 of Set 12 | kargasok
# Processing Record 18 of Set 12 | antalaha
# Processing Record 19 of Set 12 | seydi
# Processing Record 20 of Set 12 | belyy yar
# Processing Record 21 of Set 12 | kone
# Processing Record 22 of Set 12 | puerto cabezas
# Processing Record 23 of Set 12 | aykhal
# Processing Record 24 of Set 12 | bezhetsk
# Processing Record 25 of Set 12 | el granada
# Processing Record 26 of Set 12 | talaja
# Processing Record 27 of Set 12 | alo
# Processing Record 28 of Set 12 | darzab
# Processing Record 29 of Set 12 | sarikei
# Processing Record 30 of Set 12 | changji
# Processing Record 31 of Set 12 | calingasta
# Processing Record 32 of Set 12 | halabjah
# Processing Record 33 of Set 12 | takoradi
# Processing Record 34 of Set 12 | dubbo
# Processing Record 35 of Set 12 | sinabang
# Processing Record 36 of Set 12 | tak
# Processing Record 37 of Set 12 | varzea da palma
# Processing Record 38 of Set 12 | gisborne
# Processing Record 39 of Set 12 | guiuan
# Processing Record 40 of Set 12 | puerto lleras
# Processing Record 41 of Set 12 | puerto santa
# Processing Record 42 of Set 12 | verkhnevilyuysk
# Processing Record 43 of Set 12 | rivne
# Processing Record 44 of Set 12 | sibolga
# Processing Record 45 of Set 12 | binbrook
# Processing Record 46 of Set 12 | tabou
# Processing Record 47 of Set 12 | port moresby
# Processing Record 48 of Set 12 | newport
# Processing Record 49 of Set 12 | bathurst
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           sisimiut  66.9395 -53.6735    -22.22        92         100
# 1     coronel suarez -37.4547 -61.9334     16.64        93          12
# 2          boa vista   2.8197 -60.6733     28.99        65          75
# 3          grytviken -54.2811 -36.5092      1.78        95         100
# 4  port-aux-francais -49.3500  70.2167      7.42        94         100
#
#    Wind Speed Country        Date
# 0        1.48      GL  1738804537
# 1        2.75      AR  1738804539
# 2        5.14      BR  1738804488
# 3        3.82      GS  1738804541
# 4        9.41      TF  1738804542

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 sisimiut  66.9395 -53.6735    -22.22        92         100
# 1           coronel suarez -37.4547 -61.9334     16.64        93          12
# 2                boa vista   2.8197 -60.6733     28.99        65          75
# 3                grytviken -54.2811 -36.5092      1.78        95         100
# 4        port-aux-francais -49.3500  70.2167      7.42        94         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.48      GL  1738804537
# 1              2.75      AR  1738804539
# 2              5.14      BR  1738804488
# 3              3.82      GS  1738804541
# 4              9.41      TF  1738804542

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (Date)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (Date)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (Date)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (Date)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy.stats import linregress

def plot_linear_regression(x_values, y_values, title, xlabel, ylabel, file_name):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Calculate regression line
    regress_values = slope * x_values + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

    # Plot scatter plot
    plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)

    # Plot regression line
    plt.plot(x_values, regress_values, "r-", label=line_eq)

    # Add labels and title
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)

    # Save and show plot
    plt.savefig(file_name)
    plt.show()

    print(f"R-squared: {rvalue**2:.3f}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              sisimiut  66.9395 -53.6735    -22.22        92         100
# 2             boa vista   2.8197 -60.6733     28.99        65          75
# 5                  tura  25.5198  90.2201     14.97        71           0
# 6                chinde  26.8212  87.7095     14.43        68           0
# 7        ribeira grande  38.5167 -28.7000     17.65        95          29
#
#          Wind Speed Country        Date
# City_ID
# 0              1.48      GL  1738804537
# 2              5.14      BR  1738804488
# 5              1.90      IN  1738804543
# 6              2.42      NP  1738804545
# 7              7.60      PT  1738804546

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           coronel suarez -37.4547  -61.9334     16.64        93          12
# 3                grytviken -54.2811  -36.5092      1.78        95         100
# 4        port-aux-francais -49.3500   70.2167      7.42        94         100
# 8                 waitangi -43.9535 -176.5597     14.34        82          62
# 9                   avarua -21.2078 -159.7750     29.03        79         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.75      AR  1738804539
# 3              3.82      GS  1738804541
# 4              9.41      TF  1738804542
# 8              1.79      NZ  1738804547
# 9              3.60      CK  1738804548

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Northern Hemisphere: Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.69

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Southern Hemisphere: Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.28

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Northern Hemisphere: Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.11

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Southern Hemisphere: Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.08

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Northern Hemisphere: Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.04

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Southern Hemisphere: Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.03

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Northern Hemisphere: Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.01

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line
regress_values = slope * x_values + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Plot the scatter plot and regression line
plt.scatter(x_values, y_values, edgecolor="black", alpha=0.8)
plt.plot(x_values, regress_values, "r-", label=line_eq)

# Add graph properties
plt.title("Southern Hemisphere: Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.legend()
plt.grid(True)

# Display the r-squared value
print(f"The r^2-value is: {rvalue**2:.2f}")

# Show the plot
plt.show()
# Out:
# The r^2-value is: 0.05

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
print("The biggest correlation I see in the linear regression lies in the Temperature vs Laditude section. .This is highly showcased in how the temerature signficantly drops the higher the Laditude is.")
# Out:
# The biggest correlation I see in the linear regression lies in the Temperature vs Laditude section. .This is highly showcased in how the temerature signficantly drops the higher the Laditude is.
